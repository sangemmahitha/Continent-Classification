# %%
import pandas as pd
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from imblearn.pipeline import Pipeline

data_df = pd.read_csv("Mapped_train_data.csv")

# %%
#To prevent warnings being displayed
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore") #ignoring the warnings

# %%
data_df = data_df.set_index("unique_id")
data_df
# Out:
#            feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# unique_id
# FFDPO1095   0.000435   0.004835   0.001156   0.001631  -0.071953  -0.524394
# VBGHGG990   0.000490   0.002811  -0.002810   0.003657  -0.100906   0.102499
# QAGOFY895   0.000521   0.005383   0.001926   0.000966  -0.115129  -0.382085
# CLKIEM667   0.000262   0.006111   0.000615   0.001377  -0.076737  -0.503232
# DQALNF634   0.000118   0.003550  -0.002475   0.003005  -0.069995  -0.016384
# ...              ...        ...        ...        ...        ...        ...
# NXKYZA785   0.000337   0.005432  -0.000475   0.002062  -0.062630  -0.335225
# VTESHP976   0.000134   0.001271  -0.001821   0.002288  -0.096010   0.109969
# ASSDSL378   0.000141   0.003483   0.001503   0.001356  -0.093397  -0.266861
# NAWQM1097   0.000433   0.006901  -0.001123   0.002094  -0.109886  -0.074557
# XWBFGT143   0.000284   0.007169  -0.001887   0.001716  -0.049234  -0.404512
#
#            feature_7  feature_8  feature_9  feature_10  ...  feature_1016  \
# unique_id                                               ...
# FFDPO1095   0.000970  -0.001261  -0.093681    0.000558  ...      0.159471
# VBGHGG990   0.000837   0.002280  -0.410796    0.000421  ...     -1.340315
# QAGOFY895   0.000861  -0.000747  -0.219491    0.000636  ...      2.244268
# CLKIEM667   0.000929  -0.002138  -0.308278    0.000585  ...      0.638294
# DQALNF634   0.000791   0.000333  -0.328246    0.000422  ...     -0.190375
# ...              ...        ...        ...         ...  ...           ...
# NXKYZA785   0.001053  -0.000508  -0.190823    0.000554  ...     -0.220692
# VTESHP976   0.000575   0.000350  -0.382421    0.000356  ...     -0.497153
# ASSDSL378   0.000748  -0.001621  -0.216470    0.000379  ...     -0.149555
# NAWQM1097   0.000897   0.001525  -0.288022    0.000381  ...     -1.444180
# XWBFGT143   0.001131  -0.000338  -0.195785    0.000560  ...     -0.286646
#
#            feature_1017  feature_1018  feature_1019  feature_1020  \
# unique_id
# FFDPO1095     -0.184401      0.759317      0.817270      0.262474
# VBGHGG990     -1.077881     -0.480608     -1.065475      0.179071
# QAGOFY895     -0.113483      0.759855      0.497908     -0.596100
# CLKIEM667     -0.210363      1.003495     -0.008541      0.340108
# DQALNF634     -0.816606     -0.321006      1.516188     -0.243600
# ...                 ...           ...           ...           ...
# NXKYZA785     -0.497202      0.866598     -0.476684      0.006773
# VTESHP976     -0.775131     -0.504023      1.749616      0.181102
# ASSDSL378     -0.598009      0.750183      0.136275      1.332982
# NAWQM1097     -0.119214      0.358852     -1.014500     -0.489160
# XWBFGT143     -0.499627      0.771402      0.025649      0.240669
#
#            feature_1021  feature_1022  feature_1023  feature_1024  class
# unique_id
# FFDPO1095     -1.294333      2.773050      0.025298     -0.361512      1
# VBGHGG990     -0.526653      2.853807     -0.303671     -1.508515      0
# QAGOFY895     -1.273147      0.710295      1.337171     -0.479146      1
# CLKIEM667     -0.457311      0.899629      1.973452     -0.684340      1
# DQALNF634     -0.758915      2.071124      0.243026     -0.237539      0
# ...                 ...           ...           ...           ...    ...
# NXKYZA785     -1.086358      1.150124      0.299896     -0.483027      0
# VTESHP976     -0.108704      1.030581     -0.077668     -0.615002      1
# ASSDSL378     -1.210167      2.557617      0.240068     -1.049251      2
# NAWQM1097     -1.343841      0.459174      0.971992     -1.581156      1
# XWBFGT143     -0.827233      2.817193      0.489154     -0.047979      4
#
# [427 rows x 1025 columns]

# %%
data_df_corr = data_df.corr()
data_df_corr
# Out:
#               feature_1  feature_2  feature_3  feature_4  feature_5  \
# feature_1      1.000000   0.456101   0.163275   0.297146  -0.428507
# feature_2      0.456101   1.000000   0.192043   0.040355  -0.429655
# feature_3      0.163275   0.192043   1.000000  -0.552842  -0.259491
# feature_4      0.297146   0.040355  -0.552842   1.000000  -0.017801
# feature_5     -0.428507  -0.429655  -0.259491  -0.017801   1.000000
# ...                 ...        ...        ...        ...        ...
# feature_1021  -0.300260  -0.449116  -0.214864   0.058969   0.333898
# feature_1022   0.063173   0.098580   0.243699  -0.283211  -0.159773
# feature_1023  -0.131761   0.212738  -0.040899  -0.053190   0.019951
# feature_1024  -0.236245  -0.107298   0.116819  -0.346040   0.183060
# class         -0.116902  -0.056563  -0.081100  -0.106115   0.139855
#
#               feature_6  feature_7  feature_8  feature_9  feature_10  ...  \
# feature_1     -0.197192   0.224033   0.077602  -0.117677    0.326235  ...
# feature_2     -0.603240   0.620635  -0.380741  -0.360654    0.566033  ...
# feature_3     -0.523580   0.110903  -0.429160   0.367385    0.246308  ...
# feature_4      0.441910  -0.083494   0.450126  -0.489250   -0.168059  ...
# feature_5      0.259203  -0.227328   0.139737   0.295293   -0.400650  ...
# ...                 ...        ...        ...        ...         ...  ...
# feature_1021   0.394313  -0.336131   0.217358   0.052896   -0.348927  ...
# feature_1022  -0.216118   0.092119  -0.379262   0.079848    0.355090  ...
# feature_1023  -0.259427   0.203657  -0.190962  -0.259847    0.120768  ...
# feature_1024  -0.261479   0.174838  -0.279198   0.213861   -0.049546  ...
# class          0.067517   0.055518   0.014888   0.151167   -0.159109  ...
#
#               feature_1016  feature_1017  feature_1018  feature_1019  \
# feature_1        -0.326562      0.056420      0.111838     -0.397305
# feature_2        -0.121155      0.186439      0.202994     -0.571655
# feature_3         0.386923      0.278818      0.260516     -0.128723
# feature_4        -0.489621     -0.344087     -0.175078     -0.075978
# feature_5         0.150631      0.073019     -0.325412      0.333500
# ...                    ...           ...           ...           ...
# feature_1021      0.059989     -0.093939     -0.189337      0.446212
# feature_1022      0.208016     -0.111136     -0.244645     -0.084406
# feature_1023      0.150918      0.147918      0.078587      0.012672
# feature_1024      0.295111      0.220484     -0.037868      0.297670
# class            -0.040041      0.031894      0.009461      0.071146
#
#               feature_1020  feature_1021  feature_1022  feature_1023  \
# feature_1        -0.021998     -0.300260      0.063173     -0.131761
# feature_2        -0.113435     -0.449116      0.098580      0.212738
# feature_3        -0.096288     -0.214864      0.243699     -0.040899
# feature_4         0.107710      0.058969     -0.283211     -0.053190
# feature_5        -0.016360      0.333898     -0.159773      0.019951
# ...                    ...           ...           ...           ...
# feature_1021      0.247393      1.000000     -0.270273      0.082288
# feature_1022     -0.239884     -0.270273      1.000000     -0.128335
# feature_1023     -0.031049      0.082288     -0.128335      1.000000
# feature_1024      0.115736      0.192212      0.053470      0.126487
# class             0.111078      0.071250     -0.024376     -0.023301
#
#               feature_1024     class
# feature_1        -0.236245 -0.116902
# feature_2        -0.107298 -0.056563
# feature_3         0.116819 -0.081100
# feature_4        -0.346040 -0.106115
# feature_5         0.183060  0.139855
# ...                    ...       ...
# feature_1021      0.192212  0.071250
# feature_1022      0.053470 -0.024376
# feature_1023      0.126487 -0.023301
# feature_1024      1.000000  0.146893
# class             0.146893  1.000000
#
# [1025 rows x 1025 columns]

# %%
#Fetaure Filtering - Removing Features which are highly correlated by choosing a threshold of 0.90
#https://stackabuse.com/applying-filter-methods-in-python-for-feature-selection/
correlated_features = set()
class_feature = len(data_df_corr.columns)-1
for i in range(len(data_df_corr.columns)):
    for j in range(i):
        if abs(data_df_corr.iloc[i, j]) > 0.90:
            print("Correlation value between features {} and {} is {}".format(data_df_corr.columns[i],data_df_corr.columns[j],data_df_corr.iloc[i, j]))
            if abs(data_df_corr.iloc[i,class_feature]) > abs(data_df_corr.iloc[j,class_feature]):
                print("Correlation value between feature {} and {} is {}".format(data_df_corr.columns[i],"class",data_df_corr.iloc[i, class_feature]))
                print("Correlation value between feature {} and {} is {}".format(data_df_corr.columns[j],"class",data_df_corr.iloc[j, class_feature]))
                print("{} is highly correlated with {} than feature {} hence removing {}".format(data_df_corr.columns[i],class_feature,data_df_corr.columns[j],data_df_corr.columns[j]))
                colname = data_df_corr.columns[j]
            else:
                print("Correlation value between feature {} and {} is {}".format(data_df_corr.columns[i],"class",data_df_corr.iloc[i, class_feature]))
                print("Correlation value between feature {} and {} is {}".format(data_df_corr.columns[j],"class",data_df_corr.iloc[j, class_feature]))
                print("{} is highly correlated with {} than feature {} hence removing {}".format(data_df_corr.columns[j],class_feature,data_df_corr.columns[i],data_df_corr.columns[i]))
                colname = data_df_corr.columns[i]
            correlated_features.add(colname)
            print("="*10)
print(correlated_features)
# Out:
# Correlation value between features feature_211 and feature_18 is 0.9002594036284627
# Correlation value between feature feature_211 and class is 0.06057242732427918
# Correlation value between feature feature_18 and class is 0.06474612471957344
# feature_18 is highly correlated with 1024 than feature feature_211 hence removing feature_211
# ==========
# Correlation value between features feature_233 and feature_107 is -0.9293232002657525
# Correlation value between feature feature_233 and class is -0.07872607283508178
# Correlation value between feature feature_107 and class is 0.009806336738873267
# feature_233 is highly correlated with 1024 than feature feature_107 hence removing feature_107
# ==========
# Correlation value between features feature_233 and feature_211 is -0.9074442017416635
# Correlation value between feature feature_233 and class is -0.07872607283508178
# Correlation value between feature feature_211 and class is 0.06057242732427918
# feature_233 is highly correlated with 1024 than feature feature_211 hence removing feature_211
# ==========
# Correlation value between features feature_234 and feature_233 is 0.9034816287036811
# Correlation value between feature feature_234 and class is -0.0950837774281212
# Correlation value between feature feature_233 and class is -0.07872607283508178
# feature_234 is highly correlated with 1024 than feature feature_233 hence removing feature_233
# ==========
# Correlation value between features feature_336 and feature_162 is 0.9034662135931176
# Correlation value between feature feature_336 and class is -0.16923366107046595
# Correlation value between feature feature_162 and class is -0.2003164623123557
# feature_162 is highly correlated with 1024 than feature feature_336 hence removing feature_336
# ==========
# {'feature_233', 'feature_211', 'feature_336', 'feature_107'}

# %%
data_df.drop(columns=['feature_211', 'feature_233', 'feature_107', 'feature_336'],inplace=True)

# %%
data_df.to_csv("data_df.csv")

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, plot_confusion_matrix,f1_score,precision_score,recall_score,RocCurveDisplay,PrecisionRecallDisplay
from sklearn.model_selection import train_test_split
rs = 0

# %%
#Splitting the dataset into train dataset and test dataset
data_df_features = data_df.drop(columns=["class"]) #Extracting Features
data_df_class = data_df[["class"]] #Saving only Class labels

"""Splitting the data to Train and Test in a proportion of 80% and 20% respectively, since the data is imbalanced we
want to reserve the proportion of the imbalance in train and test set hence we would be using startify parameter which
does the splitting based on the values distribution present in the class label column"""
X_train, X_test, y_train, y_test = train_test_split(data_df_features, data_df_class, test_size=0.20, random_state=rs, stratify = data_df_class)

# %%
#Hyperparameter Tuning of K Nearest Neighbor
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
rs = 0

svm = SVC(random_state=rs)
params = [    
    {'kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'C' : np.logspace(-4, 4, 20),
    'gamma' : ['scale','auto'],
   }
]

grid_search = GridSearchCV(estimator=svm, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "f1_macro")
grid_search.fit(X_train,y_train)

svm_best = grid_search.best_estimator_
print(svm_best)
svm_best.fit(X_train, y_train) #Fitting on the train data
svm_yPred = svm_best.predict(X_test) #Predicting on test data
# Out:
# Fitting 4 folds for each of 160 candidates, totalling 640 fits
# SVC(C=29.763514416313132, random_state=0)

# %%
#Function to obtain different metrics based on predicted class labels
def print_metrics(y_test,y_pred,name):
    cm = confusion_matrix(y_test, y_pred) #Computing the Confusion Matrix
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues") #Initializing the Heatmap
    plt.xlabel("Predicted Labels") #Setting x label
    plt.ylabel("Actual Labels") #Setting y label
    plt.title("Confusion Matrix Obtained") #Setting the title
    plt.show(); #Showing the plot
    f1_value = round(f1_score(y_test,y_pred,labels=np.unique(y_pred),average='macro'),4) #Calculating F1-score value
    prec = round(precision_score(y_test,y_pred,labels=np.unique(y_pred),average='macro'),4) #Calculating Precision value
    rec = round(recall_score(y_test,y_pred,labels=np.unique(y_pred),average='macro'),4) #Calculating Recall value
    print("F1-score obtained is ",f1_value) #Printing F1-score value
    print("Precision obtained is ",prec) #Printing Precision value
    print("Recall obtained is ",rec) #Printing Recall value
    print("Classification Report obtained is :")
    print(classification_report(y_test, y_pred))
    return [f1_value,prec,rec] #return f1-score, precision and recall

# %%
results_table = []

#Performance Metrics obtained using Decision Tree
svm_list = ["SVM"]
svm_list.extend(print_metrics(y_test,svm_yPred,"SVM"))
results_table.append(svm_list)
# Out:
# F1-score obtained is  0.5208
# Precision obtained is  0.5509
# Recall obtained is  0.512
# Classification Report obtained is :
#               precision    recall  f1-score   support
#
#            0       0.57      0.75      0.65        32
#            1       0.57      0.36      0.44        11
#            2       0.60      0.60      0.60         5
#            3       0.41      0.44      0.42        16
#            4       0.60      0.41      0.49        22
#
#     accuracy                           0.55        86
#    macro avg       0.55      0.51      0.52        86
# weighted avg       0.55      0.55      0.54        86

# %%
from tqdm import tqdm
from sklearn.decomposition import PCA

svm = SVC(C=29.763514416313132, random_state=0)
f1_dict = {}

#for nf in tqdm(range(3,X_train.shape[1]+1)):
for nf in tqdm(range(3,min(X_train.shape[1],X_train.shape[0])+1)):
    f1_val = []
    pca = PCA(n_components=nf,random_state=rs)
    pca_train = pca.fit_transform(X_train)
    svm.fit(pca_train,y_train)
    pca_test = pca.transform(X_test)
    pca_test_predict = svm.predict(pca_test)
    f1_val.append(round(f1_score(y_test,pca_test_predict,labels=np.unique(pca_test_predict),average='macro'),4))
    f1_dict[nf] = round(sum(f1_val)/len(f1_val),4)
plt.figure(figsize=(12,10))
plt.plot(*zip(*sorted(f1_dict.items())),color='blue',marker='o')
Title = "Feature Selection with Dimensionality Reduction (PCA Method) for SVM"
plt.title(Title, fontsize=16)
plt.xticks(range(0,min(X_train.shape[0],X_train.shape[1])+1,30))
plt.xlabel("Number of Features", fontsize=16)
plt.ylabel("f1_score", fontsize=16)
plt.show();
f1_adasyn_svm = max(f1_dict.values())
f1_nfea_adasyn_svm =  max(f1_dict, key=f1_dict.get)
print("SVM Model - Maximum f1-score obtained using PCA is {} for the number of components = {}".format(f1_adasyn_svm,f1_nfea_adasyn_svm))
# Out:
# 100%|██████████| 339/339 [06:37<00:00,  1.17s/it]
# SVM Model - Maximum f1-score obtained using PCA is 0.5255 for the number of components = 76

# %%
svm = SVC(C=29.763514416313132, random_state=0)
pca = PCA(n_components=76,random_state=rs)

svm_pca_pipeline = Pipeline([('pca', pca), ('svm', svm)])
svm_pca_pipeline.fit(X_train,y_train)
svm_pca_pipeline_yPred = svm_pca_pipeline.predict(X_test)
svm_list = ["SVM - After Hyperparameter Tuning and Feature Selection based on PCA"]
svm_list.extend(print_metrics(y_test, svm_pca_pipeline_yPred,"SVM - PCA"))
results_table.append(svm_list)
# Out:
# F1-score obtained is  0.5255
# Precision obtained is  0.5571
# Recall obtained is  0.5183
# Classification Report obtained is :
#               precision    recall  f1-score   support
#
#            0       0.56      0.78      0.65        32
#            1       0.62      0.45      0.53        11
#            2       0.60      0.60      0.60         5
#            3       0.47      0.44      0.45        16
#            4       0.54      0.32      0.40        22
#
#     accuracy                           0.55        86
#    macro avg       0.56      0.52      0.53        86
# weighted avg       0.55      0.55      0.53        86

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from imblearn.over_sampling import ADASYN
rs = 0

svm = SVC(random_state=rs)
adasyn = ADASYN(random_state=rs)
params = [    
    {'svm__kernel' : ['linear', 'poly', 'rbf', 'sigmoid'],
    'svm__C' : np.logspace(-4, 4, 20),
    'svm__gamma' : ['scale','auto'],
   }
]

pipeline = Pipeline([('adasyn',adasyn),('svm',svm)])
grid_search = GridSearchCV(estimator=pipeline, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "f1_macro")
grid_search.fit(X_train,y_train)

svm_best = grid_search.best_estimator_
print(svm_best)
svm_best.fit(X_train, y_train) #Fitting on the train data
svm_yPred = svm_best.predict(X_test) #Predicting on test data
# Out:
# Fitting 4 folds for each of 160 candidates, totalling 640 fits
# Pipeline(steps=[('adasyn', ADASYN(random_state=0)),
#                 ('svm', SVC(C=11.288378916846883, random_state=0))])

# %%
svm_list = ["SVM-ADASYN"]
svm_list.extend(print_metrics(y_test,svm_yPred,"SVM-ADASYN"))
results_table.append(svm_list)
# Out:
# F1-score obtained is  0.5282
# Precision obtained is  0.5751
# Recall obtained is  0.5551
# Classification Report obtained is :
#               precision    recall  f1-score   support
#
#            0       0.55      0.72      0.62        32
#            1       0.75      0.27      0.40        11
#            2       0.62      1.00      0.77         5
#            3       0.35      0.38      0.36        16
#            4       0.60      0.41      0.49        22
#
#     accuracy                           0.53        86
#    macro avg       0.58      0.56      0.53        86
# weighted avg       0.56      0.53      0.52        86

# %%
from tqdm import tqdm
from sklearn.decomposition import PCA

svm = SVC(C=78.47599703514607, random_state=0)
f1_dict = {}

#for nf in tqdm(range(3,X_train.shape[1]+1)):
for nf in tqdm(range(3,min(X_train.shape[1],X_train.shape[0])+1)):
    f1_val = []
    
    svm_pipeline = Pipeline(steps=[('adasyn', ADASYN(random_state=0)),('pca' , PCA(n_components=nf,random_state=rs)),
                ('svm', SVC(C=11.288378916846883, random_state=0))])
    
    svm_pipeline.fit(X_train,y_train)
    pca_test_predict = svm_pipeline.predict(X_test)
    f1_val.append(round(f1_score(y_test,pca_test_predict,labels=np.unique(pca_test_predict),average='macro'),4))
    f1_dict[nf] = round(sum(f1_val)/len(f1_val),4)
plt.figure(figsize=(12,10))
plt.plot(*zip(*sorted(f1_dict.items())),color='blue',marker='o')
Title = "Feature Selection with Dimensionality Reduction (PCA Method) for SVM"
plt.title(Title, fontsize=16)
plt.xticks(range(0,min(X_train.shape[0],X_train.shape[1])+1,30))
plt.xlabel("Number of Features", fontsize=16)
plt.ylabel("f1_score", fontsize=16)
plt.show();
f1_adasyn_svm = max(f1_dict.values())
f1_nfea_adasyn_svm =  max(f1_dict, key=f1_dict.get)
print("SVM Model - Maximum f1-score obtained using PCA is {} for the number of components = {}".format(f1_adasyn_svm,f1_nfea_adasyn_svm))
# Out:
# 100%|██████████| 339/339 [10:58<00:00,  1.94s/it]
# SVM Model - Maximum f1-score obtained using PCA is 0.524 for the number of components = 80

# %%
svm_pca_pipeline = Pipeline(steps=[('adasyn', ADASYN(random_state=0)),('pca' , PCA(n_components=80,random_state=rs)),
                ('svm', SVC(C=11.288378916846883, random_state=0))])
svm_pca_pipeline.fit(X_train,y_train)
svm_pca_pipeline_yPred = svm_pca_pipeline.predict(X_test)
svm_list = ["SVM ADASYN- After Hyperparameter Tuning and Feature Selection based on PCA"]
svm_list.extend(print_metrics(y_test, svm_pca_pipeline_yPred,"SVM - PCA"))
results_table.append(svm_list)
# Out:
# F1-score obtained is  0.524
# Precision obtained is  0.5371
# Recall obtained is  0.5327
# Classification Report obtained is :
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        32
#            1       0.71      0.45      0.56        11
#            2       0.57      0.80      0.67         5
#            3       0.40      0.38      0.39        16
#            4       0.47      0.41      0.44        22
#
#     accuracy                           0.51        86
#    macro avg       0.54      0.53      0.52        86
# weighted avg       0.52      0.51      0.51        86

# %%
#Tabulating the obtained results and displaying the results by formatting
results_df = pd.DataFrame(results_table,columns = ["Classifier","f1-score","Precision","Recall"])
with pd.option_context('display.precision', 4):
    formatted_table=(results_df.style.background_gradient(cmap ='Blues'))
formatted_table
# Out:
# <style type="text/css">
# #T_89a7e_row0_col1, #T_89a7e_row0_col3, #T_89a7e_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_89a7e_row0_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_89a7e_row1_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_89a7e_row1_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_89a7e_row1_col3 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_89a7e_row2_col1, #T_89a7e_row2_col2, #T_89a7e_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_89a7e_row3_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_89a7e_row3_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# </style>
# <table id="T_89a7e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Classifier</th>
#       <th class="col_heading level0 col1" >f1-score</th>
#       <th class="col_heading level0 col2" >Precision</th>
#       <th class="col_heading level0 col3" >Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89a7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89a7e_row0_col0" class="data row0 col0" >SVM</td>
#       <td id="T_89a7e_row0_col1" class="data row0 col1" >0.5208</td>
#       <td id="T_89a7e_row0_col2" class="data row0 col2" >0.5509</td>
#       <td id="T_89a7e_row0_col3" class="data row0 col3" >0.5120</td>
#     </tr>
#     <tr>
#       <th id="T_89a7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89a7e_row1_col0" class="data row1 col0" >SVM - After Hyperparameter Tuning and Feature Selection based on PCA</td>
#       <td id="T_89a7e_row1_col1" class="data row1 col1" >0.5255</td>
#       <td id="T_89a7e_row1_col2" class="data row1 col2" >0.5571</td>
#       <td id="T_89a7e_row1_col3" class="data row1 col3" >0.5183</td>
#     </tr>
#     <tr>
#       <th id="T_89a7e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89a7e_row2_col0" class="data row2 col0" >SVM-ADASYN</td>
#       <td id="T_89a7e_row2_col1" class="data row2 col1" >0.5282</td>
#       <td id="T_89a7e_row2_col2" class="data row2 col2" >0.5751</td>
#       <td id="T_89a7e_row2_col3" class="data row2 col3" >0.5551</td>
#     </tr>
#     <tr>
#       <th id="T_89a7e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89a7e_row3_col0" class="data row3 col0" >SVM ADASYN- After Hyperparameter Tuning and Feature Selection based on PCA</td>
#       <td id="T_89a7e_row3_col1" class="data row3 col1" >0.5240</td>
#       <td id="T_89a7e_row3_col2" class="data row3 col2" >0.5371</td>
#       <td id="T_89a7e_row3_col3" class="data row3 col3" >0.5327</td>
#     </tr>
#   </tbody>
# </table>
